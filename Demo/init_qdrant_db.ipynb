# %%
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct, VectorParams, Distance

# 1. Create local database
client = QdrantClient(path=r"/home/mohammed/Documents/GitHub/Capstone-AI-SE/Demo/qdrant_local_db")

# 2. Create collection
client.create_collection(
    collection_name="trial",
    vectors_config=VectorParams(size=128, distance=Distance.COSINE)
)

# 3. All 25 points from your data
points = [
    # Pid '1', cam_id 0 (IDs 0-9)
    PointStruct(id=0, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=1, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=2, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=3, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=4, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=5, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=6, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=7, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=8, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=9, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    
    # Pid '2', cam_id 0 (IDs 10-17)
    PointStruct(id=10, vector=[0.0] * 128, payload={'Pid': '2', 'coords': [85, 291, 137, 386], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=11, vector=[0.0] * 128, payload={'Pid': '2', 'coords': [85, 291, 137, 386], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=12, vector=[0.0] * 128, payload={'Pid': '2', 'coords': [85, 291, 137, 386], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=13, vector=[0.0] * 128, payload={'Pid': '2', 'coords': [85, 291, 137, 386], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=14, vector=[0.0] * 128, payload={'Pid': '2', 'coords': [85, 291, 137, 386], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=15, vector=[0.0] * 128, payload={'Pid': '2', 'coords': [85, 291, 137, 386], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=16, vector=[0.0] * 128, payload={'Pid': '2', 'coords': [85, 291, 137, 386], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=17, vector=[0.0] * 128, payload={'Pid': '2', 'coords': [85, 291, 137, 386], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    
    # Pid '1', cam_id 1 (IDs 18-24)
    PointStruct(id=18, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [778, 519, 849, 654], 'cam_id': 1, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=19, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [778, 519, 849, 654], 'cam_id': 1, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=20, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [778, 519, 849, 654], 'cam_id': 1, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=21, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [778, 519, 849, 654], 'cam_id': 1, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=22, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [778, 519, 849, 654], 'cam_id': 1, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=23, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [778, 519, 849, 654], 'cam_id': 1, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
    PointStruct(id=24, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [778, 519, 849, 654], 'cam_id': 1, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
]

# 4. Insert all points
client.upsert(collection_name="trial", points=points)

print(f"Successfully inserted all {len(points)} points into 'trial' collection!")

# 5. Verify insertion
records = client.scroll(collection_name="trial", limit=100, with_payload=True, with_vectors=False)[0]
print(f"\nTotal records in database: {len(records)}")

# Show first few records
print("\nFirst 3 records:")
for r in records[:3]:
    print(f"  ID: {r.id}, Payload: {r.payload}")

# Show summary by Pid and cam_id
from collections import Counter
pids = [r.payload['Pid'] for r in records]
cam_ids = [r.payload['cam_id'] for r in records]
print(f"\nSummary:")
print(f"  PIDs: {dict(Counter(pids))}")
print(f"  Camera IDs: {dict(Counter(cam_ids))}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       5 client = QdrantClient(path=r"/home/mohammed/Documents/GitHub/Capstone-AI-SE/Demo/qdrant_local_db")
#       7 # 2. Create collection
# ----> 8 client.create_collection(
#       9     collection_name="trial",
#      10     vectors_config=VectorParams(size=128, distance=Distance.COSINE)
#      11 )
#      13 # 3. All 25 points from your data
#      14 points = [
#      15     # Pid '1', cam_id 0 (IDs 0-9)
#      16     PointStruct(id=0, vector=[0.0] * 128, payload={'Pid': '1', 'coords': [648, 478, 714, 596], 'cam_id': 0, 'frame_count': 7, 'isDisabled': None, 'isElderly': None, 'potentiallyLost': None}),
#    (...)
# ...
